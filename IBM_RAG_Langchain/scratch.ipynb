# %% [markdown]
# ## RAG - Retrieval Augmented Generation
#
#
# - RAG is the practice of providing additional context or domain-specificity to general-purpose per-trained large langugae models
# ![image.png](attachment:image.png)
